# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
import json
import pandas as pd
from config import api_key
from pandas.io.json import json_normalize

# %%
# Save config information.
url = "https://apps.bea.gov/api/data/?&UserID="+api_key+"&method=GETDATASETLIST&"

#url = "http://www.bea.gov/api/data/?&amp;UserID="+api_key+"&amp;method=GetData&amp;DataSetName=IIP&amp;TypeOfInvestment=FinLiabsFoa&amp;Component=Pos&amp;Frequency=QNSA&amp;Year=2013&amp;ResultFormat=xml
    
print(requests.get(url))

print(requests.get(url).json())
# Out:
# <Response [200]>
# {'BEAAPI': {'Request': {'RequestParam': [{'ParameterName': 'METHOD', 'ParameterValue': 'GETDATASETLIST'}, {'ParameterName': 'USERID', 'ParameterValue': 'E098DA86-033D-4B74-A6D6-15047B0006DD'}]}, 'Results': {'Dataset': [{'DatasetName': 'NIPA', 'DatasetDescription': 'Standard NIPA tables'}, {'DatasetName': 'NIUnderlyingDetail', 'DatasetDescription': 'Standard NI underlying detail tables'}, {'DatasetName': 'MNE', 'DatasetDescription': 'Multinational Enterprises'}, {'DatasetName': 'FixedAssets', 'DatasetDescription': 'Standard Fixed Assets tables'}, {'DatasetName': 'ITA', 'DatasetDescription': 'International Transactions Accounts'}, {'DatasetName': 'IIP', 'DatasetDescription': 'International Investment Position'}, {'DatasetName': 'GDPbyIndustry', 'DatasetDescription': 'GDP by Industry'}, {'DatasetName': 'InputOutput', 'DatasetDescription': 'Input-Output Data'}, {'DatasetName': 'UnderlyingGDPbyIndustry', 'DatasetDescription': 'Underlying GDP by Industry'}, {'DatasetName': 'IntlServTrade', 'DatasetDescription': 'International Services Trade'}, {'DatasetName': 'Regional', 'DatasetDescription': 'Regional data sets'}, {'DatasetName': 'APIDatasetMetaData', 'DatasetDescription': 'Metadata about other API datasets'}]}}}

# %%
#response["BEAAPI"]["Results"]["Dataset"]

response = requests.get(url).json()


print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "BEAAPI": {
#         "Request": {
#             "RequestParam": [
#                 {
#                     "ParameterName": "USERID",
#                     "ParameterValue": "E098DA86-033D-4B74-A6D6-15047B0006DD"
#                 },
#                 {
#                     "ParameterName": "METHOD",
#                     "ParameterValue": "GETDATASETLIST"
#                 }
#             ]
#         },
#         "Results": {
#             "Dataset": [
#                 {
#                     "DatasetDescription": "Standard NIPA tables",
#                     "DatasetName": "NIPA"
#                 },
#                 {
#                     "DatasetDescription": "Standard NI underlying detail tables",
#                     "DatasetName": "NIUnderlyingDetail"
#                 },
#                 {
#                     "DatasetDescription": "Multinational Enterprises",
#                     "DatasetName": "MNE"
#                 },
#                 {
#                     "DatasetDescription": "Standard Fixed Assets tables",
#                     "DatasetName": "FixedAssets"
#                 },
#                 {
#                     "DatasetDescription": "International Transactions Accounts",
#                     "DatasetName": "ITA"
#                 },
#                 {
#                     "DatasetDescription": "International Investment Position",
#                     "DatasetName": "IIP"
#                 },
#                 {
#                     "DatasetDescription": "GDP by Industry",
#                     "DatasetName": "GDPbyIndustry"
#                 },
#                 {
#                     "DatasetDescription": "Input-Output Data",
#                     "DatasetName": "InputOutput"
#                 },
#                 {
#                     "DatasetDescription": "Underlying GDP by Industry",
#                     "DatasetName": "UnderlyingGDPbyIndustry"
#                 },
#                 {
#                     "DatasetDescription": "International Services Trade",
#                     "DatasetName": "IntlServTrade"
#                 },
#                 {
#                     "DatasetDescription": "Regional data sets",
#                     "DatasetName": "Regional"
#                 },
#                 {
#                     "DatasetDescription": "Metadata about other API datasets",
#                     "DatasetName": "APIDatasetMetaData"
#                 }
#             ]
#         }
#     }
# }

# %%
response["BEAAPI"]["Results"]["Dataset"]
df = pd.DataFrame(response["BEAAPI"]["Results"]["Dataset"])
df.head(200)
# Out:
#                 DatasetName                    DatasetDescription
# 0                      NIPA                  Standard NIPA tables
# 1        NIUnderlyingDetail  Standard NI underlying detail tables
# 2                       MNE             Multinational Enterprises
# 3               FixedAssets          Standard Fixed Assets tables
# 4                       ITA   International Transactions Accounts
# 5                       IIP     International Investment Position
# 6             GDPbyIndustry                       GDP by Industry
# 7               InputOutput                     Input-Output Data
# 8   UnderlyingGDPbyIndustry            Underlying GDP by Industry
# 9             IntlServTrade          International Services Trade
# 10                 Regional                    Regional data sets
# 11       APIDatasetMetaData     Metadata about other API datasets

# %%
url_regional=f"https://apps.bea.gov/api/data/?&UserID={api_key}&method=GetData&datasetname=Regional&TableName=SAEXP1&GeoFIPS=00000&LineCode=3&Year=2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019&ResultFormat=JSON"
response = requests.get(url_regional).json()
response
# Out:
# {'BEAAPI': {'Request': {'RequestParam': [{'ParameterName': 'TABLENAME',
#      'ParameterValue': 'SAEXP1'},
#     {'ParameterName': 'USERID',
#      'ParameterValue': 'E098DA86-033D-4B74-A6D6-15047B0006DD'},
#     {'ParameterName': 'YEAR',
#      'ParameterValue': '2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019'},
#     {'ParameterName': 'RESULTFORMAT', 'ParameterValue': 'JSON'},
#     {'ParameterName': 'GEOFIPS', 'ParameterValue': '00000'},
#     {'ParameterName': 'LINECODE', 'ParameterValue': '3'},
#     {'ParameterName': 'METHOD', 'ParameterValue': 'GETDATA'},
#     {'ParameterName': 'DATASETNAME', 'ParameterValue': 'REGIONAL'}]},
#   'Results': {'Statistic': 'Total personal consumption expenditures: Durable goods',
#    'UnitOfMeasure': 'Millions of current dollars',
#    'PublicTable': 'SAEXP1 Durable goods',
#    'UTCProductionTime': '2020-09-06T03:18:01.067',
#    'NoteRef': ' ',
#    'Dimensions': [{'Name': 'Code', 'DataType': 'string', 'IsValue': '0'},
#     {'Name': 'GeoFips', 'DataType': 'string', 'IsValue': '0'},
#     {'Name': 'GeoName', 'DataType': 'string', 'IsValue': '0'},
#     {'Name': 'TimePeriod', 'DataType': 'string', 'IsValue': '0'},
#     {'Name': 'DataValue', 'DataType': 'numeric', 'IsValue': '1'},
#     {'Name': 'CL_UNIT', 'DataType': 'string', 'IsValue': '0'},
#     {'Name': 'UNIT_MULT', 'DataType': 'numeric', 'IsValue': '0'}],
#    'Data': [{'Code': 'SAEXP1-3',
#      'GeoFips': '00000',
#      'GeoName': 'United States',
#      'TimePeriod': '2006',
#      'CL_UNIT': 'Millions of current dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '1,158,333.1'},
#     {'Code': 'SAEXP1-3',
#      'GeoFips': '00000',
#      'GeoName': 'United States',
#      'TimePeriod': '2007',
#      'CL_UNIT': 'Millions of current dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '1,188,043.0'},
#     {'Code': 'SAEXP1-3',
#      'GeoFips': '00000',
#      'GeoName': 'United States',
#      'TimePeriod': '2008',
#      'CL_UNIT': 'Millions of current dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '1,098,760.6'},
#     {'Code': 'SAEXP1-3',
#      'GeoFips': '00000',
#      'GeoName': 'United States',
#      'TimePeriod': '2009',
#      'CL_UNIT': 'Millions of current dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '1,012,121.3'},
#     {'Code': 'SAEXP1-3',
#      'GeoFips': '00000',
#      'GeoName': 'United States',
#      'TimePeriod': '2010',
#      'CL_UNIT': 'Millions of current dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '1,048,962.5'},
#     {'Code': 'SAEXP1-3',
#      'GeoFips': '00000',
#      'GeoName': 'United States',
#      'TimePeriod': '2011',
#      'CL_UNIT': 'Millions of current dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '1,093,498.8'},
#     {'Code': 'SAEXP1-3',
#      'GeoFips': '00000',
#      'GeoName': 'United States',
#      'TimePeriod': '2012',
#      'CL_UNIT': 'Millions of current dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '1,144,221.0'},
#     {'Code': 'SAEXP1-3',
#      'GeoFips': '00000',
#      'GeoName': 'United States',
#      'TimePeriod': '2013',
#      'CL_UNIT': 'Millions of current dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '1,189,413.3'},
#     {'Code': 'SAEXP1-3',
#      'GeoFips': '00000',
#      'GeoName': 'United States',
#      'TimePeriod': '2014',
#      'CL_UNIT': 'Millions of current dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '1,242,075.5'},
#     {'Code': 'SAEXP1-3',
#      'GeoFips': '00000',
#      'GeoName': 'United States',
#      'TimePeriod': '2015',
#      'CL_UNIT': 'Millions of current dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '1,305,896.9'},
#     {'Code': 'SAEXP1-3',
#      'GeoFips': '00000',
#      'GeoName': 'United States',
#      'TimePeriod': '2016',
#      'CL_UNIT': 'Millions of current dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '1,352,645.1'},
#     {'Code': 'SAEXP1-3',
#      'GeoFips': '00000',
#      'GeoName': 'United States',
#      'TimePeriod': '2017',
#      'CL_UNIT': 'Millions of current dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '1,412,569.8'},
#     {'Code': 'SAEXP1-3',
#      'GeoFips': '00000',
#      'GeoName': 'United States',
#      'TimePeriod': '2018',
#      'CL_UNIT': 'Millions of current dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '1,475,584.8'}],
#    'Notes': [{'NoteRef': ' ',
#      'NoteText': 'Last updated: October 3, 2019-- new PCE by state statistics for 2018; revised statistics for 2014-2017.'}]}}}

# %%
#Total personal consumption expenditures
#SAGDP5N (Subsidies)
df = pd.DataFrame(response["BEAAPI"]["Results"]["Data"])
#df.count
df
# Out:
#         Code GeoFips        GeoName TimePeriod                      CL_UNIT  \
# 0   SAEXP1-3   00000  United States       2006  Millions of current dollars
# 1   SAEXP1-3   00000  United States       2007  Millions of current dollars
# 2   SAEXP1-3   00000  United States       2008  Millions of current dollars
# 3   SAEXP1-3   00000  United States       2009  Millions of current dollars
# 4   SAEXP1-3   00000  United States       2010  Millions of current dollars
# 5   SAEXP1-3   00000  United States       2011  Millions of current dollars
# 6   SAEXP1-3   00000  United States       2012  Millions of current dollars
# 7   SAEXP1-3   00000  United States       2013  Millions of current dollars
# 8   SAEXP1-3   00000  United States       2014  Millions of current dollars
# 9   SAEXP1-3   00000  United States       2015  Millions of current dollars
# 10  SAEXP1-3   00000  United States       2016  Millions of current dollars
# 11  SAEXP1-3   00000  United States       2017  Millions of current dollars
# 12  SAEXP1-3   00000  United States       2018  Millions of current dollars
#
#    UNIT_MULT    DataValue
# 0          6  1,158,333.1
# 1          6  1,188,043.0
# 2          6  1,098,760.6
# 3          6  1,012,121.3
# 4          6  1,048,962.5
# 5          6  1,093,498.8
# 6          6  1,144,221.0
# 7          6  1,189,413.3
# 8          6  1,242,075.5
# 9          6  1,305,896.9
# 10         6  1,352,645.1
# 11         6  1,412,569.8
# 12         6  1,475,584.8
